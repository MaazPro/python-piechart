# %% [markdown]
# <a href="https://colab.research.google.com/github/MaazPro/python-piechart/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
slices = [50,20,15,15]
depts = ['Sales', 'Production', 'HR','Finance']

cols = ['magenta', 'cyan','brown','gold']
plt.pie(slices, labels=depts, colors=cols, startangle=90, explode=(0,0.2,0,0), shadow=True, autopct='%.1f%%')

plt.title('Wipro')
plt.legend()
plt.show()
